# %%
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9372  0.9268  0.9414  0.9352  0.9347  0.9351  0.0048
# MAE (testset)     0.7375  0.7324  0.7424  0.7343  0.7380  0.7369  0.0034
# Fit time          0.56    0.55    0.51    0.54    0.59    0.55    0.03
# Test time         0.05    0.05    0.07    0.07    0.07    0.06    0.01
# {'test_rmse': array([0.93720329, 0.92679437, 0.94144727, 0.93517316, 0.93465454]),
#  'test_mae': array([0.73751098, 0.73238587, 0.7423958 , 0.73430768, 0.73798802]),
#  'fit_time': (0.5558929443359375,
#   0.5499751567840576,
#   0.505976676940918,
#   0.5436346530914307,
#   0.5928776264190674),
#  'test_time': (0.04860806465148926,
#   0.046022653579711914,
#   0.07115817070007324,
#   0.07164907455444336,
#   0.07307910919189453)}
